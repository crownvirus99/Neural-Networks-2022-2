# %%
import numpy as np
import pandas as pd

# Load data
data=pd.read_csv('neo.csv')

data.sample(10)
# Out:
#              id               name  est_diameter_min  est_diameter_max  \
# 54507   3158122        (2003 QB30)          0.011603          0.025944
# 83656   2216523  216523 (2001 HY7)          0.201630          0.450858
# 19262   3599862        (2012 DE31)          0.121494          0.271669
# 32352  54110059          (2021 CX)          0.006677          0.014929
# 27413   3566463         (2011 KE3)          0.044112          0.098637
# 89479   3748472        (2016 FU12)          0.011080          0.024777
# 32979   3354737       (2006 UF185)          0.133216          0.297879
# 69229   3740043       (2016 AG165)          0.183889          0.411188
# 56651   3838021         (2019 BV2)          0.021113          0.047211
# 1454    3893382          (2019 WW)          0.031956          0.071456
#
#        relative_velocity  miss_distance orbiting_body  sentry_object  \
# 54507       31666.476551   1.631904e+07         Earth          False
# 83656       77296.490129   4.735532e+07         Earth          False
# 19262       96000.698483   5.405558e+07         Earth          False
# 32352       50037.635114   2.711344e+07         Earth          False
# 27413       18035.577818   2.032878e+07         Earth          False
# 89479       33632.222690   2.409876e+07         Earth          False
# 32979       65467.513230   7.101140e+07         Earth          False
# 69229       44840.847212   5.397301e+07         Earth          False
# 56651       52264.372320   3.495889e+06         Earth          False
# 1454        52637.661525   2.473135e+07         Earth          False
#
#        absolute_magnitude  hazardous
# 54507                26.8      False
# 83656                20.6       True
# 19262                21.7       True
# 32352                28.0      False
# 27413                23.9      False
# 89479                26.9      False
# 32979                21.5      False
# 69229                20.8      False
# 56651                25.5      False
# 1454                 24.6      False

# %%
# Import LabelEncoder
from sklearn import preprocessing

# Creating labelEncoder
le = preprocessing.LabelEncoder()

# %%
# Spliting data into Feature and
X=data[['est_diameter_min', 'est_diameter_max', 'relative_velocity', 'miss_distance', 'absolute_magnitude']]
y=data['hazardous']

# Import train_test_split function
from sklearn.model_selection import train_test_split

# Split dataset into training set and test set
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=42)  # 70% training and 30% test

# %%
# Import MLPClassifer 
from sklearn.neural_network import MLPClassifier

# Create model object
clf = MLPClassifier(hidden_layer_sizes=(6,5),
                    random_state=5,
                    verbose=True,
                    learning_rate_init=0.01)

# Fit data onto the model
clf.fit(X_train,y_train)
# Out:
# Iteration 1, loss = 7.67979376
# Iteration 2, loss = 7.45001583
# Iteration 3, loss = 7.34759584
# Iteration 4, loss = 7.11793376
# Iteration 5, loss = 7.06731324
# Iteration 6, loss = 6.90352949
# Iteration 7, loss = 6.77073375
# Iteration 8, loss = 6.86300272
# Iteration 9, loss = 7.00660068
# Iteration 10, loss = 6.84807226
# Iteration 11, loss = 6.92349764
# Iteration 12, loss = 6.23018874
# Iteration 13, loss = 5.42637748
# Iteration 14, loss = 1.91088366
# Iteration 15, loss = 1.65853347
# Iteration 16, loss = 0.35022999
# Iteration 17, loss = 0.34885463
# Iteration 18, loss = 0.34229908
# Iteration 19, loss = 0.33610577
# Iteration 20, loss = 0.33290801
# Iteration 21, loss = 0.33318164
# Iteration 22, loss = 0.32880477
# Iteration 23, loss = 0.32806028
# Iteration 24, loss = 0.32569885
# Iteration 25, loss = 0.32411050
# Iteration 26, loss = 0.32239285
# Iteration 27, loss = 0.32190498
# Iteration 28, loss = 0.32187898
# Iteration 29, loss = 0.32023740
# Iteration 30, loss = 0.32066706
# Iteration 31, loss = 0.32095596
# Iteration 32, loss = 0.32056109
# Iteration 33, loss = 0.31953496
# Iteration 34, loss = 0.31873118
# Iteration 35, loss = 0.31892456
# Iteration 36, loss = 0.31882102
# Iteration 37, loss = 0.31912782
# Iteration 38, loss = 0.31889170
# Iteration 39, loss = 0.31878293
# Iteration 40, loss = 0.31888324
# Iteration 41, loss = 0.31896901
# Iteration 42, loss = 0.31922840
# Iteration 43, loss = 0.31888203
# Iteration 44, loss = 0.31906990
# Iteration 45, loss = 0.31922220
# Training loss did not improve more than tol=0.000100 for 10 consecutive epochs. Stopping.
# MLPClassifier(hidden_layer_sizes=(6, 5), learning_rate_init=0.01,
#               random_state=5, verbose=True)

# %%
# Make prediction on test dataset
ypred=clf.predict(X_test)

# Import accuracy score 
from sklearn.metrics import accuracy_score

# Calcuate accuracy
accuracy_score(y_test,ypred)
# Out:
# 0.9026090785659242
